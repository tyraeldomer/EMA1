# %% [markdown]
# ### Number 1: Turning Tables (15 points)

# %% [markdown]
# ### Number 2: Dating Norms (30 points)

# %%
day = int(input("Day: "))
month = int(input("Month: "))
year = int(input("Year: "))

thirty_days = [4,6,9,11]
thirtyone_days = [1,3,5,7,8,12]

indicator = str(day)
st = ["1","21","31"] 
nd = ["2","22"]
rd = ["3","23"]

if day <= 28 and month == 2:
    if indicator in st and month == 2:
        print("It is the",day,"st day of the month of February of the year",year)

    elif indicator in nd and month == 2:
        print("It is the",day,"nd day of the month of February of the year",year)

    elif indicator in rd and month == 2:
        print("It is the",day,"rd day of the month of February of the year",year)

    
elif day > 28 and month == 2:
    if year % 4 == 0:
        print("Date is invalid.")
elif day > 29 and month == 2:
    if year % 100 == 0:
        print("Date is invalid.")


elif indicator in st:
        
    if month in thirty_days and day <= 30 :
        if month == 4:
            print("It is the",day,"st day of the month of April of the year",year)
        elif month == 6:
            print("It is the",day,"st day of the month of June of the year",year)
        elif month == 9:
            print("It is the",day,"st day of the month of September of the year",year)
        elif month == 11:
            print("It is the",day,"st day of the month of November of the year",year)
            
    elif month in thirtyone_days and day <= 31:
        if month == 1:
            print("It is the",day,"st day of the month of January of the year",year)
        elif month == 3:
            print("It is the",day,"st day of the month of March of the year",year)
        elif month == 5:
            print("It is the",day,"st day of the month of May of the year",year)
        elif month == 7:
            print("It is the",day,"st day of the month of July of the year",year)
        elif month == 8:
            print("It is the",day,"st day of the month of August of the year",year)
        elif month == 10:
            print("It is the",day,"st day of the month of October of the year",year)
        elif month == 12:
            print("It is the",day,"st day of the month of December of the year",year)
            
    elif month in thirty_days and day > 30:
        print("Date is invalid.")
        
    elif month in thirtyone_days and day > 31:
        print("Date is invalid.")
            
if indicator in nd:
    
    if month in thirty_days and day <= 30:
        if month == 4:
            print("It is the",day,"nd day of the month of April of the year",year)
        elif month == 6:
            print("It is the",day,"nd day of the month of June of the year",year)
        elif month == 9:
            print("It is the",day,"nd day of the month of September of the year",year)
        elif month == 11:
            print("It is the",day,"nd day of the month of November of the year",year)
    
    elif month in thirtyone_days and day <= 31:
        if month == 1:
            print("It is the",day,"nd day of the month of January of the year",year)
        elif month == 3:
            print("It is the",day,"nd day of the month of March of the year",year)
        elif month == 5:
            print("It is the",day,"nd day of the month of May of the year",year)
        elif month == 7:
            print("It is the",day,"nd day of the month of July of the year",year)
        elif month == 8:
            print("It is the",day,"nd day of the month of August of the year",year)
        elif month == 10:
            print("It is the",day,"nd day of the month of October of the year",year)
        elif month == 12:
            print("It is the",day,"nd day of the month of December of the year",year)
            
    elif month in thirty_days and day > 30:
        print("Date is invalid.")
            
if indicator in rd:

    if month in thirty_days and day <= 30:
        if month == 4:
            print("It is the",day,"rd day of the month of April of the year",year)
        elif month == 6:
            print("It is the",day,"rd day of the month of June of the year",year)
        elif month == 9:
            print("It is the",day,"rd day of the month of September of the year",year)
        elif month == 11:
            print("It is the",day,"rd day of the month of November of the year",year)
    
    elif month in thirtyone_days and day <= 31:
        if month == 1:
            print("It is the",day,"rd day of the month of January of the year",year)
        elif month == 3:
            print("It is the",day,"rd day of the month of March of the year",year)
        elif month == 5:
            print("It is the",day,"rd day of the month of May of the year",year)
        elif month == 7:
            print("It is the",day,"rd day of the month of July of the year",year)
        elif month == 8:
            print("It is the",day,"rd day of the month of August of the year",year)
        elif month == 10:
            print("It is the",day,"rd day of the month of October of the year",year)
        elif month == 12:
            print("It is the",day,"rd day of the month of December of the year",year)
# Out:
# Day: 21
# Month: 4
# Year: 2001
# It is the 21 st day of the month of April of the year 2001

# %% [markdown]
# ### Number 3: Followers (15 points)

# %%
number = int(input("Enter a number: "))

def obedient(number):
    for x in range(1,number):

# %% [markdown]
# ### Number 4: Go Forth and Multiply (15 pts)

# %%
parameter = int(input("Enter number: "))

for i in range(1,parameter + 1):
    print(i + x, end = " ")
    print()
    for x in range(1,parameter + 1):
        print(i * x, end = " ")
# Out:
# Enter number: 6
# 5
# 1 2 3 4 5 6 8
# 2 4 6 8 10 12 9
# 3 6 9 12 15 18 10
# 4 8 12 16 20 24 11
# 5 10 15 20 25 30 12
# 6 12 18 24 30 36

# %% [markdown]
# ### Number 5: Avatar (25 pts)

# %%
fire = []
earth = []
water = []

winner1 = len(fire)
winner2 = len(earth)
winner3 = len(water)

ans1 = input("Do you prefer (a)the mountains, (b)the city or (c)the beach? ")
if (ans1 == "a") or (ans1 == "A"):
    fire.append("a")
elif (ans1 == "b") or (ans1 == "B"):
    earth.append("b")
elif (ans1 == "c") or (ans1 == "C"):
    water.append("c")
else:
    print("Sorry, you inputted a wrong letter. Please start again.")

ans2 = input("Do you prefer (a)yoghurt, (b)ice cream or (c)gelato? ")
if (ans2 == "a") or (ans2 == "A"):
    earth.append("a")
elif (ans2 == "b") or (ans2 == "B"):
    water.append("b")
elif (ans2 == "c") or (ans2 == "C"):
    fire.append("c")
else:
    print("Sorry, you inputted a wrong letter. Please start again.")

ans3 = input("Do you prefer (a)reading, (b)singing or (c)writing? ")
if (ans3 == "a") or (ans3 == "A"):
    water.append("a")
elif (ans3 == "b") or (ans3 == "B"):
    fire.append("b")
elif (ans3 == "c") or (ans3 == "C"):
    earth.append("c")
else:
    print("Sorry, you inputted a wrong letter. Please start again.")

ans4 = input("Do you prefer (a)sweet, (b)salty or (c)spicy food? ")
if (ans4 == "a") or (ans4 == "A"):
    earth.append("a")
elif (ans4 == "b") or (ans4 == "B"):
    water.append("b")
elif (ans4 == "c") or (ans4 == "C"):
    fire.append("c")
else:
    print("Sorry, you inputted a wrong letter. Please start again.")

ans5 = input("Do you prefer (a)cats, (b)dogs or (c)fish? ")
if (ans5 == "a") or (ans5 == "A"):
    earth.append("a")
elif (ans5 == "b") or (ans5 == "B"):
    fire.append("b")
elif (ans5 == "c") or (ans5 == "C"):
    water.append("c")
else:
    print("Sorry, you inputted a wrong letter. Please start again.")
        
if len(fire) > len(earth) and len(fire) > len(water):
    print("Your element is fire.")
elif len(earth) > len(fire) and len(earth) > len(water):
    print("Your element is earth.")
elif len(water) > len(earth) and len(water) > len(fire):
    print("Your element is water.")

elif len(fire) == len(water):
    print("Your element is fire.")
elif len(fire) == len(earth):
    print("Your element is earth")
elif len(earth) == len(water):
    print("Your element is water")
# Out:
# Do you prefer (a)the mountains, (b)the city or (c)the beach? a
# Do you prefer (a)yoghurt, (b)ice cream or (c)gelato? c
# Do you prefer (a)reading, (b)singing or (c)writing? a
# Do you prefer (a)sweet, (b)salty or (c)spicy food? a
# Do you prefer (a)cats, (b)dogs or (c)fish? a
# Your element is earth
